# %% [markdown]
# How do we mechanically prove a theorem given only incidences?

# %%
import numpy#import numpy
import json

from METHODS.extract_info import *
from METHODS.methods import *
from CLASSES.point import *
from CLASSES.line import *
from CLASSES.conic import *
from CLASSES.construction import *

# %%
filename = "testfiles/pappos3.cjs"

constr = extract_information(filename)

# %%
constr.print_objects()
constr.print_incidences()
# Out:
# The points in this construction are: A, B, C, D, E, F, G, H, K.
# The lines in this construction are: a, b, c, d, e, f, g, h, k.
# There are no conics in this construction.
# Listing incidences...
# -> Points:
# --> Point A is incident to a, e, g
# --> Point B is incident to a, f, h
# --> Point C is incident to b, c, h
# --> Point D is incident to b, d, g
# --> Point E is incident to d, a, c
# --> Point F is incident to e, b, f
# --> Point G is incident to e, k, c
# --> Point H is incident to k, h, g
# --> Point K is incident to f, d
# -> Lines:
# --> Line a is incident to A, B, E
# --> Line b is incident to C, D, F
# --> Line c is incident to C, E, G
# --> Line d is incident to D, E, K
# --> Line e is incident to A, F, G
# --> Line f is incident to K, B, F
# --> Line g is incident to A, H, D
# --> Line h is incident to C, H, B
# --> Line k is incident to G, H

# %%
constr.calculate_point_non_degeneracies()
constr.calculate_line_non_degeneracies()
# Out:
# -79.71625853999998
# -104.25201421999991
# 0.0035365410933121135
# -90.67062223446261
# -44.918820286438816
# -46.487386831265304
# -48.522704569744235
# 74.51515206
# 37.74829240625067
# 33.271708815081965
# 16.487127946448737
# 33.22766047773545
# 54.86046608235171
# 49.370092308580894
# -41.242434139234966
# -20.426403053808812
# 0.0004495195721332335
# 26.389063150783016
# -42.93702301408413
# -21.271282686592222
# -22.014793649845142
# -22.97954382560917
# 0.004669572846666207
# 18.39095160182615
# 42.14697678904243
# 9.108603793675703
# 20.87738949011545
# 11.767031880180234
# 99.05090774
# -41.971502674842625
# 44.22607250954463
# -18.310310307112427
# -0.0012112309992147186
# 23.666912112095968
# -54.88545845251245
# -54.823826124772296
# -79.75959698736999
# -57.764177869162566
# -29.340246499472713
# 47.73713576147183
# 23.651074140939908
# 24.476129722513495
# 25.5466972852284
# -45.74713237517716
# -25.792283801371177
# -0.0009408756759799065
# 10.677170338502204
# ...

# %%
print(len(constr.non_deg_points))
print(len(constr.non_deg_lines))
# Out:
# 42
# 46
